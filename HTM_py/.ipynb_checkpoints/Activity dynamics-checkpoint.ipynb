# %%
# %load_ext autoreload
# %autoreload 2
from util import *
from ArcExpression import get_Arc_expression, normalize_Arc, normalize_IEG

from scipy import stats
import numpy as np
from IPython.core.pylabtools import figsize
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
proj_meta = load_meta()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-df6239e9e5d9> in <module>()
# ----> 1 proj_meta = load_meta()
#
# C:\Code\ProjectAnalysis\Analysis_HTM\HTM_py\util.py in load_meta()
#       6
#       7 def load_meta():
# ----> 8     proj_meta = pickle.load(open("C:/Users/vision/Desktop/HTM_meta_py/HTM_projmeta.py", "rb"))
#       9     return proj_meta
#      10
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/vision/Desktop/HTM_meta_py/HTM_projmeta.py'

# %%
tone_resp_early = [np.hstack(tone_responses(proj_meta, site, 3, 20, 80))
             for site in range(9)]

tone_resp_late = [np.hstack(tone_responses(proj_meta, site, 13, 20, 80))
             for site in range(9)]

# %%
mean_early = np.vstack([np.mean(tone_resp_early[k], axis=1) for k in range(9)])
mean_late = np.vstack([np.mean(tone_resp_late[k], axis=1) for k in range(9)])

# %%
mean_early = elemwise_subtract(mean_early, np.mean(mean_early[:,10:19], axis=1))
mean_late = elemwise_subtract(mean_late, np.mean(mean_late[:,10:19], axis=1))

# %%
plt.plot(np.mean(mean_early, axis=0))
plt.plot(np.mean(mean_late, axis=0))
plt.axvline(20, color='k', linestyle='--')

# %%
plt.plot(np.mean(tmp, axis=0))
